# %% [markdown]
# run carla_data_collector.py

# %%
# !gdown --fuzzy https://drive.google.com/file/d/1ZwIQiBf4N_OVhqj0UV0fGBqeOi1HkjFK/view?usp=sharing
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1ZwIQiBf4N_OVhqj0UV0fGBqeOi1HkjFK
# From (redirected): https://drive.google.com/uc?id=1ZwIQiBf4N_OVhqj0UV0fGBqeOi1HkjFK&confirm=t&uuid=7cb65d2a-46b7-4074-a471-a81e3a90793a
# To: /content/carla_dataset.zip
# 100% 2.78G/2.78G [00:29<00:00, 94.3MB/s]

# %%
# !unzip -q carla_dataset.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: carla_dataset/night/segmentation/night_000004.png
#   inflating: carla_dataset/night/segmentation/night_000005.png
#   inflating: carla_dataset/night/segmentation/night_000006.png
#   inflating: carla_dataset/night/segmentation/night_000007.png
#   inflating: carla_dataset/night/segmentation/night_000008.png
#   inflating: carla_dataset/night/segmentation/night_000009.png
#   inflating: carla_dataset/night/segmentation/night_000010.png
#   inflating: carla_dataset/night/segmentation/night_000011.png
#   inflating: carla_dataset/night/segmentation/night_000012.png
#   inflating: carla_dataset/night/segmentation/night_000013.png
#   inflating: carla_dataset/night/segmentation/night_000014.png
#   inflating: carla_dataset/night/segmentation/night_000015.png
#   inflating: carla_dataset/night/segmentation/night_000016.png
#   inflating: carla_dataset/night/segmentation/night_000017.png
# ...

# %%
# !python yolo_data_preprocessor.py carla_dataset
# Out:
# Created YOLOv11 dataset structure at: yolo_dataset
# 🚀 Starting complete YOLOv11 preprocessing pipeline...
# ...
#
# 📁 Step 1: Converting CARLA dataset to YOLOv11 format...
# Converting CARLA dataset to YOLOv11 format...
# Loading CARLA dataset...
# Loaded 1000 samples for day
# Loaded 1000 samples for night
# Loaded 1000 samples for rain
# Loaded 1000 samples for fog
# Total samples to convert: 4000
#
# Processing train split (2400 samples)...
# Converting train: 100% 2400/2400 [00:14<00:00, 161.27it/s]
#
# Processing val split (800 samples)...
# Converting val: 100% 800/800 [00:03<00:00, 240.04it/s]
#
# Processing test split (800 samples)...
# Converting test: 100% 800/800 [00:03<00:00, 221.84it/s]
# Created dataset configuration: yolo_dataset/dataset.yaml
# Generated conversion report: yolo_dataset/analysis/conversion_report.md
#
# ✅ Dataset conversion completed!
# 📊 Total images: 4000
# 🏷️  Total annotations: 3248
# ⚠️  Annotation issues: 0
#
# ...

# %%
# !pip install -q ultralytics
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 18.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 106.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 93.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 58.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 103.3 MB/s eta 0:00:00

# %%
# !python yolo_dataset/train_yolo.py
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Training YOLOv11 on dataset: /content/yolo_dataset
# Classes: ['car', 'pedestrian', 'traffic_light']
# Number of classes: 3
# ...
# 100% 5.90M/5.90M [00:00<00:00, 74.7MB/s]
# Starting training...
# WARNING ⚠️ 'label_smoothing' is deprecated and will be removed in in the future.
# WARNING ⚠️ 'save_hybrid' is deprecated and will be removed in in the future.
# Ultralytics 8.3.151 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !zip -r carla_yolo_training.zip carla_yolo_training/
# Out:
# updating: carla_yolo_training/ (stored 0%)
# updating: carla_yolo_training/carla_segmentation_v12/ (stored 0%)
# updating: carla_yolo_training/carla_segmentation_v12/val_batch2_pred.jpg (deflated 7%)
# updating: carla_yolo_training/carla_segmentation_v12/val_batch2_labels.jpg (deflated 7%)
# updating: carla_yolo_training/carla_segmentation_v12/val_batch0_pred.jpg (deflated 6%)
# updating: carla_yolo_training/carla_segmentation_v12/BoxPR_curve.png (deflated 17%)
# updating: carla_yolo_training/carla_segmentation_v12/val_batch1_labels.jpg (deflated 7%)
# updating: carla_yolo_training/carla_segmentation_v12/MaskP_curve.png (deflated 11%)
# updating: carla_yolo_training/carla_segmentation_v12/BoxP_curve.png (deflated 11%)
# updating: carla_yolo_training/carla_segmentation_v12/BoxF1_curve.png (deflated 12%)
# updating: carla_yolo_training/carla_segmentation_v12/MaskPR_curve.png (deflated 16%)
# updating: carla_yolo_training/carla_segmentation_v12/confusion_matrix.png (deflated 31%)
# ...

# %%
# !ls -ltrh
# Out:
# total 2.8G
# drwxr-xr-x 1 root root 4.0K Jun  5 13:38 sample_data
# -rw-r--r-- 1 root root 2.6G Jun  6 18:55 carla_dataset.zip
# drwxr-xr-x 7 root root 4.0K Jun  6 20:48 carla_dataset
# -rw-r--r-- 1 root root  40K Jun  7 00:08 yolo_data_preprocessor.py
# drwxr-xr-x 6 root root 4.0K Jun  7 00:08 yolo_dataset
# -rw-r--r-- 1 root root 5.9M Jun  7 00:11 yolo11n-seg.pt
# -rw-r--r-- 1 root root 5.4M Jun  7 00:11 yolo11n.pt
# drwxr-xr-x 4 root root 4.0K Jun  7 05:07 carla_yolo_training
# -rw-r--r-- 1 root root 7.9M Jun  7 05:14 yolo_dataset.zip
# drwx------ 6 root root 4.0K Jun  7 05:14 drive
# -rw-r--r-- 1 root root 133M Jun  7 05:18 carla_yolo_training.zip

# %%
# !zip -r yolo_dataset.zip yolo_dataset/
# Out:
#   adding: yolo_dataset/ (stored 0%)
#   adding: yolo_dataset/dataset.yaml (deflated 24%)
#   adding: yolo_dataset/val/ (stored 0%)
#   adding: yolo_dataset/val/labels/ (stored 0%)
#   adding: yolo_dataset/val/labels/rain_000803.txt (stored 0%)
#   adding: yolo_dataset/val/labels/fog_000879.txt (stored 0%)
#   adding: yolo_dataset/val/labels/day_000984.txt (deflated 74%)
#   adding: yolo_dataset/val/labels/night_000127.txt (deflated 73%)
#   adding: yolo_dataset/val/labels/night_000549.txt (stored 0%)
#   adding: yolo_dataset/val/labels/day_000442.txt (deflated 75%)
#   adding: yolo_dataset/val/labels/night_000048.txt (deflated 73%)
#   adding: yolo_dataset/val/labels/rain_000700.txt (deflated 74%)
#   adding: yolo_dataset/val/labels/day_000560.txt (deflated 66%)
#   adding: yolo_dataset/val/labels/night_000216.txt (deflated 72%)
#   adding: yolo_dataset/val/labels/fog_000824.txt (stored 0%)
#   adding: yolo_dataset/val/labels/rain_000387.txt (stored 0%)
# ...

# %%
# !rm -r yolo_dataset/**/images/*.png

# %%
# !cp /content/carla_yolo_training.zip drive/MyDrive/

# %%
# !cp /content/yolo_dataset.zip drive/MyDrive/
